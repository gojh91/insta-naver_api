# %%
import requests
import json
import urllib.request
import datetime as dt
import pandas as pd
import csv

# %%
i = 0
self.makeCSV()
df = pd.read_csv(self.csvname + '.csv')
print('1####')
for each_url in df['each_url']:
    print(i)
    i += 1
    print(each_url)
    dict_a = {}
    try:
        each_resp = requests.get(each_url)
        each_json_data = json.loads(each_resp.text)
        print('2####')

        dict_a['each_url'] = each_url
        each_location = each_json_data['data']['shortcode_media']['location']['name']
        dict_a['each_location'] = each_location
        address_json = each_json_data['data']['shortcode_media']['location']['address_json']
        dict_a['address_json'] = address_json
        self.list_a.append(dict_a)
        print('3####')
    except Exception as e:
        print(e)

# %%
import scrapy
import requests
import json
import urllib.request
import datetime as dt
import pandas as pd
import csv
from instascrapy1.items import Instascrapy1Item


class Isntascrapy1Spider(scrapy.Spider):
    name = 'instascrapy1'
    allowed_domains = ['instagram.com']
    start_urls = ['http://instagram.com/']
    scvname = ""

    def start_requests(self):
        df = pd.read_csv(self.csvname + '.csv')
        for each_url in df['each_url']:
            print("each_url : " + each_url)
            yield scrapy.Request(url=each_url, callback=self.parse)

    def parse(self, response):
        print('response.url : ' + response.url)
        each_json_data = json.loads(response.body)
        
        print("each_json_data : " + str(each_json_data))
        item = Instascrapy1Item()
        each_url	each_location	address_json
        item['each_url'] = response.url
        
        item['each_location'] = each_json_data['data']['shortcode_media']['location']['name']
        
        item['address_json'] = each_json_data['data']['shortcode_media']['location']['address_json']

# %%
with open('키즈존_each_test.json') as json_file2:
    json_data2 = json.load(json_file2)

# %%
result_df2 = pd.DataFrame(json_data2,columns=['each_url', 'each_location' ,'address_json'])

# %%
result_df2
# Out:
#                                               each_url  \
# 0    https://www.instagram.com/graphql/query/?query...
# 1    https://www.instagram.com/graphql/query/?query...
# 2    https://www.instagram.com/graphql/query/?query...
# 3    https://www.instagram.com/graphql/query/?query...
# 4    https://www.instagram.com/graphql/query/?query...
# 5    https://www.instagram.com/graphql/query/?query...
# 6    https://www.instagram.com/graphql/query/?query...
# 7    https://www.instagram.com/graphql/query/?query...
# 8    https://www.instagram.com/graphql/query/?query...
# 9    https://www.instagram.com/graphql/query/?query...
# 10   https://www.instagram.com/graphql/query/?query...
# 11   https://www.instagram.com/graphql/query/?query...
# 12   https://www.instagram.com/graphql/query/?query...
# 13   https://www.instagram.com/graphql/query/?query...
# 14   https://www.instagram.com/graphql/query/?query...
# 15   https://www.instagram.com/graphql/query/?query...
# ...

# %%
df3 = result_df2.drop_duplicates('each_url')

# %%
df3
# Out:
#                                               each_url  \
# 0    https://www.instagram.com/graphql/query/?query...
# 1    https://www.instagram.com/graphql/query/?query...
# 2    https://www.instagram.com/graphql/query/?query...
# 3    https://www.instagram.com/graphql/query/?query...
# 4    https://www.instagram.com/graphql/query/?query...
# 5    https://www.instagram.com/graphql/query/?query...
# 6    https://www.instagram.com/graphql/query/?query...
# 7    https://www.instagram.com/graphql/query/?query...
# 8    https://www.instagram.com/graphql/query/?query...
# 9    https://www.instagram.com/graphql/query/?query...
# 10   https://www.instagram.com/graphql/query/?query...
# 11   https://www.instagram.com/graphql/query/?query...
# 12   https://www.instagram.com/graphql/query/?query...
# 13   https://www.instagram.com/graphql/query/?query...
# 14   https://www.instagram.com/graphql/query/?query...
# 15   https://www.instagram.com/graphql/query/?query...
# ...

# %%
with open('키즈존_each.json') as json_file3:
    json_data3 = json.load(json_file3)

# %%
result_df3 = pd.DataFrame(json_data3,columns=['each_url', 'each_location' ,'address_json'])

# %%
df4 = result_df3.drop_duplicates('each_url')

# %%
df4
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df4['address_json'][0]
# Out:
# '{"street_address": "\\uc778\\ucc9c \\uc5f0\\uc218\\uad6c \\uc625\\ub828\\ub3d9 351-4", "zip_code": "21953", "city_name": "Incheon, Korea", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}'

# %%
df4.iloc[0]
# Out:
# each_url         https://www.instagram.com/graphql/query/?query...
# each_location                                                 밀우커피
# address_json     {"street_address": "\uc778\ucc9c \uc5f0\uc218\...
# Name: 0, dtype: object

# %%
df4.iloc[1]
# Out:
# each_url         https://www.instagram.com/graphql/query/?query...
# each_location                                               황금동어느곳
# address_json     {"street_address": "", "zip_code": "", "city_n...
# Name: 1, dtype: object

# %%
df4.to_csv('키즈존_each.csv')

# %%
df4['each_url'][0]
# Out:
# 'https://www.instagram.com/graphql/query/?query_hash=477b65a610463740ccdb83135b2014db&variables=%7B%22shortcode%22:%22B17tgsyBuxZ%22%7D'

# %%
df = pd.read_csv(r'C:\Users\student\Desktop\insta_crawling\인스타 끝난 자료\키즈존.csv')

# %%
df['each_url'][0]
# Out:
# 'https://www.instagram.com/graphql/query/?query_hash=477b65a610463740ccdb83135b2014db&variables={"shortcode":"B176xW3HjBa"}'

# %%
with open('키즈존_test.json') as json_file3:
    json_data3 = json.load(json_file3)

# %%
result_df3 = pd.DataFrame(json_data3,columns=['each_url', 'each_location' ,'address_json'])

# %%
df4 = result_df3.drop_duplicates('each_url')

# %%
df4
# Out:
#                                              each_url        each_location  \
# 0   https://www.instagram.com/graphql/query/?query...               황금동어느곳
# 1   https://www.instagram.com/graphql/query/?query...               황금동어느곳
# 2   https://www.instagram.com/graphql/query/?query...                 밀우커피
# 3   https://www.instagram.com/graphql/query/?query...                 룰리커피
# 4   https://www.instagram.com/graphql/query/?query...           168계단 모노레일
# 5   https://www.instagram.com/graphql/query/?query...           올모스트홈 경리단길
# 6   https://www.instagram.com/graphql/query/?query...            파라다이스시티호텔
# 7   https://www.instagram.com/graphql/query/?query...             아난티펜트하우스
# 8   https://www.instagram.com/graphql/query/?query...               황금동어느곳
# 9   https://www.instagram.com/graphql/query/?query...               황금동어느곳
# 10  https://www.instagram.com/graphql/query/?query...               창원 사파동
# ...

# %%
df4['each_url'][0]
# Out:
# 'https://www.instagram.com/graphql/query/?query_hash=477b65a610463740ccdb83135b2014db&variables=%7B%22shortcode%22:%22B17oYxGF_2U%22%7D'

# %%
import urllib.parse

url = urllib.parse.unquote(df4['each_url'][0])

# %%
url
# Out:
# 'https://www.instagram.com/graphql/query/?query_hash=477b65a610463740ccdb83135b2014db&variables={"shortcode":"B17oYxGF_2U"}'

# %%
type(df4['address_json'][6])
# Out:
# str

# %%
dict(df4['address_json'][6])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-655ea9a87563> in <module>
# ----> 1 dict(df4['address_json'][6])
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %%
result_df4['is'] = result_df4['address_json'].map(lambda x : 1 if '서울' in result_df4['address_json'][0].split(':')[1].split(',')[0] else 0)

# %%
with open(r'C:\Users\student\Desktop\insta_crawling\인스타 끝난 자료\아이와가볼만한곳_each.json') as json_file4:
    json_data4 = json.load(json_file4)

# %%
result_df4 = pd.DataFrame(json_data4,columns=['each_url', 'each_location' ,'address_json'])

# %%
result_df4
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df4 = result_df4.drop_duplicates('each_url')

# %%
df4
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df4.to_csv('아이와가볼만한곳_each.csv')

# %%
str1 = df4['address_json'][0]

# %%
"\\uc11c\\uc6b8\\uc2dc \\uad11\\uc9c4\\uad6c \\uc544\\ucc28\\uc0b0\\ub85c 272 \\ub354\\uc0f5\\uc2a4\\ud0c0\\uc2dc\\ud2f0\\ubab0 \\uc9c0\\ud5581\\uce35".encode('cp949')
# Out:
# b'\\uc11c\\uc6b8\\uc2dc \\uad11\\uc9c4\\uad6c \\uc544\\ucc28\\uc0b0\\ub85c 272 \\ub354\\uc0f5\\uc2a4\\ud0c0\\uc2dc\\ud2f0\\ubab0 \\uc9c0\\ud5581\\uce35'

# %%
str1.encode('cp949')
str1.decode('cp949')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-79-c59a8ab7a39d> in <module>
#       1 str1.encode('cp949')
# ----> 2 str1.decode('cp949')
#
# AttributeError: 'str' object has no attribute 'decode'

# %%
str1.encode('utf-8')
# Out:
# b'{"street_address": "\\uc11c\\uc6b8\\uc2dc \\uad11\\uc9c4\\uad6c \\uc544\\ucc28\\uc0b0\\ub85c 272 \\ub354\\uc0f5\\uc2a4\\ud0c0\\uc2dc\\ud2f0\\ubab0 \\uc9c0\\ud5581\\uce35", "zip_code": "05065", "city_name": "Seoul, Korea", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}'

# %%
str1.encode('ascii')
# Out:
# b'{"street_address": "\\uc11c\\uc6b8\\uc2dc \\uad11\\uc9c4\\uad6c \\uc544\\ucc28\\uc0b0\\ub85c 272 \\ub354\\uc0f5\\uc2a4\\ud0c0\\uc2dc\\ud2f0\\ubab0 \\uc9c0\\ud5581\\uce35", "zip_code": "05065", "city_name": "Seoul, Korea", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}'

# %%
str1.encode('utf-16')
# Out:
# b'\xff\xfe{\x00"\x00s\x00t\x00r\x00e\x00e\x00t\x00_\x00a\x00d\x00d\x00r\x00e\x00s\x00s\x00"\x00:\x00 \x00"\x00\\\x00u\x00c\x001\x001\x00c\x00\\\x00u\x00c\x006\x00b\x008\x00\\\x00u\x00c\x002\x00d\x00c\x00 \x00\\\x00u\x00a\x00d\x001\x001\x00\\\x00u\x00c\x009\x00c\x004\x00\\\x00u\x00a\x00d\x006\x00c\x00 \x00\\\x00u\x00c\x005\x004\x004\x00\\\x00u\x00c\x00c\x002\x008\x00\\\x00u\x00c\x000\x00b\x000\x00\\\x00u\x00b\x008\x005\x00c\x00 \x002\x007\x002\x00 \x00\\\x00u\x00b\x003\x005\x004\x00\\\x00u\x00c\x000\x00f\x005\x00\\\x00u\x00c\x002\x00a\x004\x00\\\x00u\x00d\x000\x00c\x000\x00\\\x00u\x00c\x002\x00d\x00c\x00\\\x00u\x00d\x002\x00f\x000\x00\\\x00u\x00b\x00a\x00b\x000\x00 \x00\\\x00u\x00c\x009\x00c\x000\x00\\\x00u\x00d\x005\x005\x008\x001\x00\\\x00u\x00c\x00e\x003\x005\x00"\x00,\x00 \x00"\x00z\x00i\x00p\x00_\x00c\x00o\x00d\x00e\x00"\x00:\x00 \x00"\x000\x005\x000\x006\x005\x00"\x00,\x00 \x00"\x00c\x00i\x00t\x00y\x00_\x00n\x00a\x00m\x00e\x00"\x00:\x00 \x00"\x00S\x00e\x00o\x00u\x00l\x00,\x00 \x
# ...

# %%
str1.encode().decode('unicode_escape')
# Out:
# '{"street_address": "서울시 광진구 아차산로 272 더샵스타시티몰 지하1층", "zip_code": "05065", "city_name": "Seoul, Korea", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}'

# %%
df4['address_json'][0].encode().decode('unicode_escape')
# Out:
# '{"street_address": "서울시 광진구 아차산로 272 더샵스타시티몰 지하1층", "zip_code": "05065", "city_name": "Seoul, Korea", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}'

# %%
result_df4
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
result_df4['address_json'] = result_df4['address_json'].map(lambda x : x.encode().decode('unicode_escape') if x is not None else None)

# %%
result_df4['address_json'].value_counts()
# Out:
# {"street_address": "서면 팔봉산로 368", "zip_code": "", "city_name": "Hongcheon", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}                                                                         251
# {"street_address": "", "zip_code": "", "city_name": "Seoul, Korea", "region_name": "", "country_code": "KR", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}                                                                                 116
# {"street_address": "", "zip_code": "", "city_name": "", "region_name": "", "country_code": "", "exact_city_match": false, "exact_region_match": false, "exact_country_match": false}                                                                                               111
# ...

# %%
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
result_df4['address'] = result_df4['address_json'].map(lambda x: x.split(':')[1].split(',')[0] if x is not None else None)

# %%
result_df4['address'] = result_df4['address'].map(lambda x : x.replace('"','') if x is not None else None)

# %%
result_df4
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df = result_df4[['each_url', 'each_location', 'address' ]]

# %%
df
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df = df.dropna()

# %%
df
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df = df[df['address'] != " "]

# %%
df
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 16    https://www.instagram.com/graphql/query/?query...
# 18    https://www.instagram.com/graphql/query/?query...
# 19    https://www.instagram.com/graphql/query/?query...
# 20    https://www.instagram.com/graphql/query/?query...
# 21    https://www.instagram.com/graphql/query/?query...
# 22    https://www.instagram.com/graphql/query/?query...
# 25    https://www.instagram.com/graphql/query/?query...
# 26    https://www.instagram.com/graphql/query/?query...
# 29    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df.to_csv('아이와가볼만한곳_location.csv')

# %%
with open(r'C:\Users\student\Desktop\insta_crawling\인스타 끝난 자료\키즈존_each.json') as json_file21:
    json_data21 = json.load(json_file21)

# %%
result_df21 = pd.DataFrame(json_data21,columns=['each_url', 'each_location' ,'address_json'])

# %%
result_df21
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df21 = result_df21.drop_duplicates('each_url')

# %%
df21
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
result_df21['address_json'] = result_df21['address_json'].map(lambda x : x.encode().decode('unicode_escape') if x is not None else None)

# %%
result_df21
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
result_df21['address'] = result_df21['address_json'].map(lambda x: x.split(':')[1].split(',')[0] if x is not None else None)

# %%
result_df21['address'] = result_df21['address'].map(lambda x : x.replace('"','') if x is not None else None)

# %%
df21 = result_df21[['each_url', 'each_location', 'address' ]]

# %%
df21 = df21.dropna()

# %%
df21
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 1     https://www.instagram.com/graphql/query/?query...
# 2     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 6     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 8     https://www.instagram.com/graphql/query/?query...
# 9     https://www.instagram.com/graphql/query/?query...
# 10    https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 12    https://www.instagram.com/graphql/query/?query...
# 13    https://www.instagram.com/graphql/query/?query...
# 14    https://www.instagram.com/graphql/query/?query...
# 15    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df21 = df21[df21['address'] != " "]

# %%
df21
# Out:
#                                                each_url  \
# 0     https://www.instagram.com/graphql/query/?query...
# 3     https://www.instagram.com/graphql/query/?query...
# 4     https://www.instagram.com/graphql/query/?query...
# 5     https://www.instagram.com/graphql/query/?query...
# 7     https://www.instagram.com/graphql/query/?query...
# 11    https://www.instagram.com/graphql/query/?query...
# 16    https://www.instagram.com/graphql/query/?query...
# 17    https://www.instagram.com/graphql/query/?query...
# 18    https://www.instagram.com/graphql/query/?query...
# 19    https://www.instagram.com/graphql/query/?query...
# 21    https://www.instagram.com/graphql/query/?query...
# 22    https://www.instagram.com/graphql/query/?query...
# 23    https://www.instagram.com/graphql/query/?query...
# 24    https://www.instagram.com/graphql/query/?query...
# 25    https://www.instagram.com/graphql/query/?query...
# 27    https://www.instagram.com/graphql/query/?query...
# ...

# %%
df.to_csv('키즈존_location.csv')
